# %% [markdown]
# # Working with Strings in Python: Financial Markets Examples
#
# This notebook demonstrates various ways to work with strings in Python, including manipulating them, searching within them, and using them in control structures. We will use examples from financial markets to illustrate these concepts.

# %% [markdown]
# ## 1. String Manipulation
#
# ### Example: Concatenating Strings
# Let's concatenate the name of a company with its stock symbol.

# %%
# Company name and stock symbol
company_name = "Apple Inc."
stock_symbol = "AAPL"

# Concatenate strings
full_name = company_name + " (" + stock_symbol + ")"
print(full_name)
# Out:
# Apple Inc. (AAPL)

# %% [markdown]
# ### Example: Formatting Strings
# Let's format a string to include the current stock price.

# %%
# Stock price
stock_price = 150.75

# Format string
message = f"The current stock price of {company_name} ({stock_symbol}) is ${stock_price:.2f}"
print(message)

#to make it as a percentage
close_stock_price = 155
gain = close_stock_price/stock_price-1

#print gain message where we say "The return on the stock is XX.XX%
message += f/nThe return on the stock is {gain*100:.2f}%"gain"
# Out:
# The current stock price of Apple Inc. (AAPL) is $150.75

# %% [markdown]
# ### Example: Splitting Strings
# Let's split a string containing a list of stock symbols.

# %%
# String of stock symbols
symbols = "AAPL, GOOGL, MSFT, AMZN"

# Split string into a list
symbol_list = symbols.split(", ")
print(symbol_list)
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'AMZN']

# %% [markdown]
# ## 2. Searching Within Strings
#
# ### Example: Checking for Substrings
# Let's check if a stock symbol is in a list of symbols.

# %%
# Check if a symbol is in the list
search_symbol = "GOOGL"

if search_symbol in symbols:
    print(f"{search_symbol} is in the list of symbols.")
else:
    print(f"{search_symbol} is not in the list of symbols.")

# %% [markdown]
# ### Example: Finding Substring Position
# Let's find the position of a stock symbol in a string.

# %%
# Find the position of a symbol in the string
position = symbols.find("MSFT")
print(f"The position of MSFT in the string is: {position}")

# How do you find the position of the actual word MSFT in the list? 
# Use symbol_list instead of symbol, as we have split them up
position = symbol_list.find("MSFT")
print(f"The position of MSFT in the list is: {position}")

hhi
# Out:
# The position of MSFT in the string is: 13
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 7
#       3 print(f"The position of MSFT in the string is: {position}")
#       5 # How do you find the position of the actual word MSFT in the list?
#       6 # Use symbol_list instead of symbol, as we have split them up
# ----> 7 position = symbol_list.find("MSFT")
#       8 print(f"The position of MSFT in the list is: {position}")
#
# AttributeError: 'list' object has no attribute 'find'

# %% [markdown]
# ## 3. Using Strings in Control Structures
#
# ### Example: Conditional Statements
# Let's use a string in an `if` statement to check the status of a stock.

# %%
# Stock status
status = "up"

# Check the status of the stock
if status == "up":
    print("The stock price is going up.")
elif status == "down":
    print("The stock price is going down.")
else:
    print("The stock price is unchanged.")
# Out:
# The stock price is going up.

# %% [markdown]
# ### Example: Looping Through Strings
# Let's loop through a list of stock symbols and print each one.

# %%
# Loop through the list of stock symbols
for symbol in symbol_list:
    print(symbol)

#note the difference from using symbol_list and symbols and how this produces the stock symbols vs simply characters. 

for x in symbols:
    print(x)

for x in symbols:
    print(x, end="")
# Out:
# AAPL
# GOOGL
# MSFT
# AMZN
# A
# A
# P
# L
# ,
#
# G
# O
# O
# G
# L
# ,
#
# M
# S
# F
# T
# ,
#
# A
# M
# Z
# N
# AAPL, GOOGL, MSFT, AMZN

# %% [markdown]
# ## 4. Common String Methods
#
# Python provides many built-in string methods:

# %%
# Common string methods
text = "  Apple Inc.  "

#This is not changing the text, but applying a method to return a value. 
print("Original:", repr(text))  # repr shows spaces
print("Upper:", text.upper())
print("Lower:", text.lower())
print("Strip:", text.strip())  # Remove leading/trailing whitespace
print("Replace:", text.replace("Apple", "Google"))
#Notice below, that applying the strip method before the starts with function gets rid of the empty space, so that the final answer is TRUE
print("StartsWith:", text.strip().startswith("Apple"))
print("EndsWith:", text.strip().endswith("Inc."))

#You can set up your variables originally, to save doing this step,
Upper_text = text.upper()
print(Upper_text)

# %% [markdown]
# ---
#
# ## 5. Character-by-Character Processing
#
# ### String Indexing and Length
#
# Strings in Python are indexed starting from 0.

# %%
# String indexing examples
word = "Python"

print("Word:", word)
print("Length:", len(word))
print("First character:", word[0])
print("Last character:", word[-1])
print("Third character:", word[2])

# Loop with index
print("\nCharacters with indices:")
for i in range(len(word)):
    print(f"Index {i}: {word[i]}")

#NOTE the back-slash inside a quote immediately before a symbol is known as the escape route - applies n as new line in between the print above
# Out:
# Word: Python
# Length: 6
# First character: P
# Last character: n
# Third character: t
#
# Characters with indices:
# Index 0: P
# Index 1: y
# Index 2: t
# Index 3: h
# Index 4: o
# Index 5: n

# %% [markdown]
# ### Character Classification
#
# Python provides methods to check what type of character you have:

# %%
# Character classification
chars = ['A', 'a', '5', ' ', '!']

for char in chars:
    print(f"\nCharacter: '{char}'")
    print(f"  Is uppercase: {char.isupper()}")
    print(f"  Is lowercase: {char.islower()}")
    print(f"  Is alphabetic: {char.isalpha()}")
    print(f"  Is digit: {char.isdigit()}")
    print(f"  Is alphanumeric: {char.isalnum()}")
    print(f"  Is space: {char.isspace()}")
# Out:
# Character: 'A'
#   Is uppercase: True
#   Is lowercase: False
#   Is alphabetic: True
#   Is digit: False
#   Is alphanumeric: True
#   Is space: False
#
# Character: 'a'
#   Is uppercase: False
#   Is lowercase: True
#   Is alphabetic: True
#   Is digit: False
#   Is alphanumeric: True
#   Is space: False
#
# Character: '5'
#   Is uppercase: False
#   Is lowercase: False
#   Is alphabetic: False
#   Is digit: True
#   Is alphanumeric: True
#   Is space: False
#
# Character: ' '
#   Is uppercase: False
#   Is lowercase: False
#   Is alphabetic: False
#   Is digit: False
#   Is alphanumeric: False
#   Is space: True
#
# Character: '!'
#   Is uppercase: False
#   Is lowercase: False
#   Is alphabetic: False
#   Is digit: False
#   Is alphanumeric: False
#   Is space: False
